# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('icon.ico')

# %%
type(pic)
# Out:
# PIL.IcoImagePlugin.IcoImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (2137, 4847, 4)

# %%
pic
# Out:
# <PIL.IcoImagePlugin.IcoImageFile image mode=RGBA size=256x256 at 0x2107E3F7780>

# %%
pic_arr.shape
# Out:
# (256, 256, 4)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
pic_red
# Out:
# array([[[248, 248, 246, 255],
#         [248, 248, 246, 255],
#         [248, 248, 246, 255],
#         ...,
#         [249, 248, 246, 255],
#         [248, 247, 245, 255],
#         [248, 247, 245, 255]],
#
#        [[248, 248, 246, 255],
#         [248, 248, 246, 255],
#         [248, 248, 246, 255],
#         ...,
#         [249, 248, 246, 255],
#         [249, 248, 246, 255],
#         [248, 247, 245, 255]],
#
#        [[247, 247, 245, 255],
#         [248, 248, 246, 255],
#         [247, 247, 245, 255],
#         ...,
#         [249, 248, 246, 255],
#         [249, 248, 246, 255],
#         [249, 248, 246, 255]],
#
#        ...,
#
#        [[248, 247, 245, 255],
#         [248, 247, 245, 255],
#         [249, 248, 246, 255],
#         ...,
#         [249, 248, 246, 255],
#         [249, 248, 246, 255],
#         [248, 247, 245, 255]],
#
#        [[248, 247, 245, 255],
#         [249, 248, 246, 255],
#         [249, 248, 246, 255],
#         ...,
#         [248, 247, 245, 255],
#         [248, 247, 245, 255],
#         [249, 248, 246, 255]],
#
#        [[249, 248, 246, 255],
#         [248, 247, 245, 255],
#         [249, 248, 246, 255],
#         ...,
#         [248, 247, 245, 255],
#         [248, 247, 245, 255],
#         [248, 247, 245, 255]]], dtype=uint8)

# %%
plt.imshow(pic_red)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.imshow(pic_red)
#
# NameError: name 'plt' is not defined

# %%
pic_red.shape
# Out:
# (256, 256, 4)

# %%
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
pic_red[:,:,2]=0

# %%
plt.imshow(pic_red)
